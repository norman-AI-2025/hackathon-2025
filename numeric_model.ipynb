# %% [markdown]
# <a href="https://colab.research.google.com/github/norman-AI-2025/hackathon-2025/blob/main/numeric_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. After defining your numeric model function:
scored_numeric = compute_numeric_risk_scores(df)  # adds 'numeric_score'

# 2. Add a text column for demo if you don't have one yet:
scored_numeric["notes"] = [
    "Always pays on time, no issues recorded.",
    "Frequently late payments, high debt and multiple reminders sent.",
    # ...add for all rows or fillna with neutral text
]

# 3. Import fusion (in Colab it's already in the same notebook, so no file import needed)
from fusion_model import compute_fusion_scores

final_df = compute_fusion_scores(
    scored_numeric,
    text_col="notes",
    numeric_col="numeric_score",
    alpha=0.6,  # 60% numeric, 40% text
)

final_df[["Applicant_Income", "Loan_Amount", "numeric_score",
          "text_score", "risk_score", "risk_label"]].head()
